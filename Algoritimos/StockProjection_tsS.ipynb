# %% [markdown]
# **Projeto de Graduação**
#
# **Projeção de Estoque**
#
# *Aluno: Victor Martins de Araújo*
#
# *Orientador: Reinaldo Garcia Cipriano*
#
# *Política (t,s,S)*
#
# *Projeção de estoque para o período de 1 ano, baseado em estratégia mista, ponto de pedido (s), ritmo de pedido (t) e no limite superior de estoque (S)*

# %%
import pandas as pd 
import numpy as np

# %%
stock_projection = pd.DataFrame(columns = ['Dia','Estoque',
'Necessidade'])
stock = 30000
s1 = 25500
s2 = 13000
order = 0
t1 = 0
T = 365
temp = 59
t = 0

for i in range(1,T):
    
    t += 1

    demand = 8 + 428*np.random.beta(1.34, 1.45)
    stock_projection = stock_projection.append({'Dia': i,'Estoque': stock,'Necessidade': demand}, ignore_index=True)
    stock -= demand

    if i == t1:
        t1 = 0
        stock += order
        order = 0

    if stock < s2 and order == 0:
        L = round(np.random.normal(55.8,14.1))
        t1 = i + L
        order = s1 - stock

    if stock < 0:
        stock = 0

    if t == temp and order == 0:
        L = round(np.random.normal(55.8,14.1))
        t1 = i + L
        t = 0
        order = s1 - stock

    
    
    

stock_projection
output = stock_projection.to_excel('StockProjection_material_3_tsS_otimo.xlsx')
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_18928\1709792331.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock_projection = stock_projection.append({'Dia': i,'Estoque': stock,'Necessidade': demand}, ignore_index=True)
# C:\Users\Victor\AppData\Local\Temp\ipykernel_18928\1709792331.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock_projection = stock_projection.append({'Dia': i,'Estoque': stock,'Necessidade': demand}, ignore_index=True)
# C:\Users\Victor\AppData\Local\Temp\ipykernel_18928\1709792331.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock_projection = stock_projection.append({'Dia': i,'Estoque': stock,'Necessidade': demand}, ignore_index=True)
# ...

# %%
for i in range(100):
    a = 
    print(a)
# Out:
# 43
# 259
# 217
# 357
# 357
# 323
# 226
# 222
# 226
# 200
# 249
# 127
# 129
# 94
# 26
# 157
# 174
# 37
# 167
# 131
# 168
# 190
# 67
# 375
# 42
# 359
# 77
# 197
# 264
# 297
# 406
# 249
# 112
# 186
# 192
# 292
# 92
# 316
# 123
# 251
# 182
# 69
# 284
# 55
# 131
# 92
# 194
# 213
# 197
# 141
# 234
# 75
# 194
# 140
# 286
# 343
# 37
# 158
# 101
# 170
# 155
# 60
# 169
# 265
# 128
# 340
# 292
# 44
# 93
# 133
# 18
# 314
# 211
# 256
# 62
# 334
# 404
# 257
# 135
# 198
# 106
# 337
# 181
# 239
# 249
# 218
# 162
# 355
# 380
# 403
# 43
# 62
# 323
# 295
# 132
# 155
# 199
# 54
# 32
# 230
